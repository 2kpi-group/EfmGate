# %%
# %load_ext autoreload
# %autoreload 2
import sys
if "../.." not in sys.path:
    sys.path.append("../..")

import numpy as np
import jax.numpy as jnp
import matplotlib.pyplot as plt

import signature.tensor_algebra as ta
from simulation.diffusion import Diffusion

import jax.numpy as jnp
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       8 import jax.numpy as jnp
#       9 import matplotlib.pyplot as plt
# ---> 11 import signature.tensor_algebra as ta
#      12 from simulation.diffusion import Diffusion
#      14 import jax.numpy as jnp
#
# File ~/efmgate/external/signature/signature/tensor_algebra.py:13
#      11 from .algebra_basis import AlgebraBasis
#      12 from .path_signature import path_to_signature, path_to_fm_signature
# ---> 13 from .expected_signature import expected_bm_signature, expected_bm_fm_signature
#      14 from .operators import G, G_inv, G_resolvent, D, D_timedep, semi_integrated_scheme, Psi, diamond
#      15 from .tensor_sequence import TensorSequence
#
# File ~/efmgate/external/signature/signature/expected_signature.py:5
#       2 import jax.numpy as jnp
#       3 from typing import Union
# ----> 5 from build.lib.signature.ode_integration import ode_solver_traj
#       6 from .tensor_sequence import TensorSequence
#       7 from .operators import G_inv
#
# ModuleNotFoundError: No module named 'build'
